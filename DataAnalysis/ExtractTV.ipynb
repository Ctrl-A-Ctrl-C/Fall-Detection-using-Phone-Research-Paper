# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
headerList = ["AX", "AY", "AZ", "GX", "GY", "GZ"]

# %%
TV_1_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_1_1.csv", delimiter = ",")
TV_1_1.columns = headerList
TV_1_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_1_1.interpolate()

TV_1_1["AX"] = pd.to_numeric(TV_1_1["AX"], errors='coerce')
TV_1_1["AY"] = pd.to_numeric(TV_1_1["AY"], errors='coerce')
TV_1_1["AZ"] = pd.to_numeric(TV_1_1["AZ"], errors='coerce')

TV_1_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Walking_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_1_1.drop(TV_1_1.index[0:130], inplace = True)
TV_1_1.drop(TV_1_1.index[150:400], inplace = True)

TV_1_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_1_1.csv", index=False) 
TV_1_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_1_1.csv", delimiter = ",")
TV_1_1 = TV_1_1.interpolate()

TV_1_1.plot(kind='line', #to produce a staced area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14,
             )

plt.title('TV_Walking_1', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
TV_1_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_1_2.csv", delimiter = ",")
TV_1_2.columns = headerList
TV_1_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_1_2.head()

TV_1_2["AX"] = pd.to_numeric(TV_1_2["AX"], errors='coerce')
TV_1_2["AY"] = pd.to_numeric(TV_1_2["AY"], errors='coerce')
TV_1_2["AZ"] = pd.to_numeric(TV_1_2["AZ"], errors='coerce')

TV_1_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Walking_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_1_2.drop(TV_1_2.index[0:110], inplace = True)
TV_1_2.drop(TV_1_2.index[140:250], inplace = True)

TV_1_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_1_2.csv", index=False) 
TV_1_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_1_2.csv", delimiter = ",")

TV_1_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Walking_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_1_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_1_3.csv", delimiter = ",")
TV_1_3.columns = headerList
TV_1_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_1_3.head()

TV_1_3["AX"] = pd.to_numeric(TV_1_3["AX"], errors='coerce')
TV_1_3["AY"] = pd.to_numeric(TV_1_3["AY"], errors='coerce')
TV_1_3["AZ"] = pd.to_numeric(TV_1_3["AZ"], errors='coerce')

TV_1_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Walking_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_1_3.drop(TV_1_3.index[0:110], inplace = True)
TV_1_3.drop(TV_1_3.index[130:400], inplace = True)

TV_1_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_1_3.csv", index=False) 
TV_1_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_1_3.csv", delimiter = ",")

TV_1_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Walking_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_2_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_2_1.csv", delimiter = ",")
TV_2_1.columns = headerList
TV_2_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_2_1.head()

TV_2_1["AX"] = pd.to_numeric(TV_2_1["AX"], errors='coerce')
TV_2_1["AY"] = pd.to_numeric(TV_2_1["AY"], errors='coerce')
TV_2_1["AZ"] = pd.to_numeric(TV_2_1["AZ"], errors='coerce')

TV_2_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Forwards_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_2_1.drop(TV_2_1.index[0:160], inplace = True)
TV_2_1.drop(TV_2_1.index[20:400], inplace = True)

TV_2_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_2_1.csv", index=False) 
TV_2_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_2_1.csv", delimiter = ",")

TV_2_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14,
             )

plt.title('TV_Falling_Forwards_1', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
TV_2_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_2_2.csv", delimiter = ",")
TV_2_2.columns = headerList
TV_2_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_2_2.head()

TV_2_2["AX"] = pd.to_numeric(TV_2_2["AX"], errors='coerce')
TV_2_2["AY"] = pd.to_numeric(TV_2_2["AY"], errors='coerce')
TV_2_2["AZ"] = pd.to_numeric(TV_2_2["AZ"], errors='coerce')

TV_2_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Forwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')
# Out:
# Text(0.5, 0, 'Time/s')

# %%
TV_2_2.drop(TV_2_2.index[0:180], inplace = True)
TV_2_2.drop(TV_2_2.index[30:400], inplace = True)

TV_2_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_2_2.csv", index=False) 
TV_2_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_2_2.csv", delimiter = ",")

TV_2_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Forwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_2_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_2_3.csv", delimiter = ",")
TV_2_3.columns = headerList
TV_2_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_2_3.head()

TV_2_3["AX"] = pd.to_numeric(TV_2_3["AX"], errors='coerce')
TV_2_3["AY"] = pd.to_numeric(TV_2_3["AY"], errors='coerce')
TV_2_3["AZ"] = pd.to_numeric(TV_2_3["AZ"], errors='coerce')

TV_2_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14,
             )

plt.title('TV_Falling_Forwards_3', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
TV_2_3.drop(TV_2_3.index[0:160], inplace = True)
TV_2_3.drop(TV_2_3.index[20:400], inplace = True)

TV_2_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_2_3.csv", index=False) 
TV_2_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_2_3.csv", delimiter = ",")

TV_2_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Forwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_3_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_3_1.csv", delimiter = ",")
TV_3_1.columns = headerList
TV_3_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_3_1.head()

TV_3_1["AX"] = pd.to_numeric(TV_3_1["AX"], errors='coerce')
TV_3_1["AY"] = pd.to_numeric(TV_3_1["AY"], errors='coerce')
TV_3_1["AZ"] = pd.to_numeric(TV_3_1["AZ"], errors='coerce')

TV_3_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Backwards_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_3_1.drop(TV_3_1.index[0:175], inplace = True)
TV_3_1.drop(TV_3_1.index[25:250], inplace = True)

TV_3_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_3_1.csv", index=False) 
TV_3_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_3_1.csv", delimiter = ",")

TV_3_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Backwards_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_3_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_3_2.csv", delimiter = ",")
TV_3_2.columns = headerList
TV_3_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_3_2.head()

TV_3_2["AX"] = pd.to_numeric(TV_3_2["AX"], errors='coerce')
TV_3_2["AY"] = pd.to_numeric(TV_3_2["AY"], errors='coerce')
TV_3_2["AZ"] = pd.to_numeric(TV_3_2["AZ"], errors='coerce')

TV_3_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Backwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_3_2.drop(TV_3_2.index[0:170], inplace = True)
TV_3_2.drop(TV_3_2.index[25:250], inplace = True)

TV_3_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_3_2.csv", index=False) 
TV_3_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_3_2.csv", delimiter = ",")

TV_3_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Backwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_3_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_3_3.csv", delimiter = ",")
TV_3_3.columns = headerList
TV_3_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_3_3.head()

TV_3_3["AX"] = pd.to_numeric(TV_3_3["AX"], errors='coerce')
TV_3_3["AY"] = pd.to_numeric(TV_3_3["AY"], errors='coerce')
TV_3_3["AZ"] = pd.to_numeric(TV_3_3["AZ"], errors='coerce')

TV_3_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Backwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_3_3.drop(TV_3_3.index[0:165], inplace = True)
TV_3_3.drop(TV_3_3.index[15:250], inplace = True)

TV_3_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_3_3.csv", index=False) 
TV_3_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_3_3.csv", delimiter = ",")

TV_3_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Backwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_4_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_4_1.csv", delimiter = ",")
TV_4_1.columns = headerList
TV_4_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_4_1.head()

TV_4_1["AX"] = pd.to_numeric(TV_4_1["AX"], errors='coerce')
TV_4_1["AY"] = pd.to_numeric(TV_4_1["AY"], errors='coerce')
TV_4_1["AZ"] = pd.to_numeric(TV_4_1["AZ"], errors='coerce')

TV_4_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Side_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_4_1.drop(TV_4_1.index[0:170], inplace = True)
TV_4_1.drop(TV_4_1.index[20:250], inplace = True)

TV_4_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_4_1.csv", index=False) 
TV_4_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_4_1.csv", delimiter = ",")

TV_4_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Side_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_4_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_4_2.csv", delimiter = ",")
TV_4_2.columns = headerList
TV_4_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_4_2.head()

TV_4_2["AX"] = pd.to_numeric(TV_4_2["AX"], errors='coerce')
TV_4_2["AY"] = pd.to_numeric(TV_4_2["AY"], errors='coerce')
TV_4_2["AZ"] = pd.to_numeric(TV_4_2["AZ"], errors='coerce')

TV_4_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Side_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_4_2.drop(TV_4_2.index[0:150], inplace = True)
TV_4_2.drop(TV_4_2.index[20:250], inplace = True)

TV_4_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_4_2.csv", index=False) 
TV_4_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_4_2.csv", delimiter = ",")

TV_4_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Side_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_4_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_4_3.csv", delimiter = ",")
TV_4_3.columns = headerList
TV_4_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_4_3.head()

TV_4_3["AX"] = pd.to_numeric(TV_4_3["AX"], errors='coerce')
TV_4_3["AY"] = pd.to_numeric(TV_4_3["AY"], errors='coerce')
TV_4_3["AZ"] = pd.to_numeric(TV_4_3["AZ"], errors='coerce')

TV_4_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Side_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_4_3.drop(TV_4_3.index[0:155], inplace = True)
TV_4_3.drop(TV_4_3.index[30:250], inplace = True)

TV_4_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_4_3.csv", index=False) 
TV_4_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_4_3.csv", delimiter = ",")

TV_4_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Falling_Side_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_5_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_5_1.csv", delimiter = ",")
TV_5_1.columns = headerList
TV_5_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_5_1.head()

TV_5_1["AX"] = pd.to_numeric(TV_5_1["AX"], errors='coerce')
TV_5_1["AY"] = pd.to_numeric(TV_5_1["AY"], errors='coerce')
TV_5_1["AZ"] = pd.to_numeric(TV_5_1["AZ"], errors='coerce')

TV_5_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14,
             )

plt.title('TV_Dropping_1', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
TV_5_1.drop(TV_5_1.index[0:165], inplace = True)
TV_5_1.drop(TV_5_1.index[28:250], inplace = True)
TV_5_1 = TV_5_1.interpolate()

TV_5_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_5_1.csv", index=False) 
TV_5_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_5_1.csv", delimiter = ",")

TV_5_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14,
             )

plt.title('TV_Dropping_1', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
TV_5_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_5_2.csv", delimiter = ",")
TV_5_2.columns = headerList
TV_5_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_5_2.head()

TV_5_2["AX"] = pd.to_numeric(TV_5_2["AX"], errors='coerce')
TV_5_2["AY"] = pd.to_numeric(TV_5_2["AY"], errors='coerce')
TV_5_2["AZ"] = pd.to_numeric(TV_5_2["AZ"], errors='coerce')

TV_5_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Dropping_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_5_2.drop(TV_5_2.index[0:185], inplace = True)
TV_5_2.drop(TV_5_2.index[25:250], inplace = True)

TV_5_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_5_2.csv", index=False) 
TV_5_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_5_2.csv", delimiter = ",")

TV_5_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14
             )

plt.title('TV_Dropping_2', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
TV_5_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesTV_5_3.csv", delimiter = ",")
TV_5_3.columns = headerList
TV_5_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
TV_5_3.head()

TV_5_3["AX"] = pd.to_numeric(TV_5_3["AX"], errors='coerce')
TV_5_3["AY"] = pd.to_numeric(TV_5_3["AY"], errors='coerce')
TV_5_3["AZ"] = pd.to_numeric(TV_5_3["AZ"], errors='coerce')

TV_5_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Dropping_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
TV_5_3.drop(TV_5_3.index[0:170], inplace = True)
TV_5_3.drop(TV_5_3.index[20:250], inplace = True)

TV_5_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_5_3.csv", index=False) 
TV_5_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesTV_5_3.csv", delimiter = ",")

TV_5_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('TV_Dropping_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()
