# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
headerList = ["AX", "AY", "AZ", "GX", "GY", "GZ"]

# %%
BD_1_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_1_1.csv", delimiter = ",")
BD_1_1.columns = headerList
BD_1_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_1_1.head()

BD_1_1["AX"] = pd.to_numeric(BD_1_1["AX"], errors='coerce')
BD_1_1["AY"] = pd.to_numeric(BD_1_1["AY"], errors='coerce')
BD_1_1["AZ"] = pd.to_numeric(BD_1_1["AZ"], errors='coerce')

BD_1_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Walking_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_1_1.drop(BD_1_1.index[0:90], inplace = True)
BD_1_1.drop(BD_1_1.index[145:250], inplace = True)

BD_1_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_1_1.csv", index=False) 
BD_1_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_1_1.csv", delimiter = ",")

BD_1_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14
             )

plt.title('BD_Walking_1', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.savefig('C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/BD_Walking_1.jpg')
plt.show()

# %%
BD_1_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_1_2.csv", delimiter = ",")
BD_1_2.columns = headerList
BD_1_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_1_2.head()

BD_1_2["AX"] = pd.to_numeric(BD_1_2["AX"], errors='coerce')
BD_1_2["AY"] = pd.to_numeric(BD_1_2["AY"], errors='coerce')
BD_1_2["AZ"] = pd.to_numeric(BD_1_2["AZ"], errors='coerce')

BD_1_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Walking_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_1_2.drop(BD_1_2.index[0:100], inplace = True)
BD_1_2.drop(BD_1_2.index[130:250], inplace = True)

BD_1_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_1_2.csv", index=False) 
BD_1_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_1_2.csv", delimiter = ",")

BD_1_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Walking_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_1_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_1_3.csv", delimiter = ",")
BD_1_3.columns = headerList
BD_1_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_1_3.head()

BD_1_3["AX"] = pd.to_numeric(BD_1_3["AX"], errors='coerce')
BD_1_3["AY"] = pd.to_numeric(BD_1_3["AY"], errors='coerce')
BD_1_3["AZ"] = pd.to_numeric(BD_1_3["AZ"], errors='coerce')

BD_1_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Walking_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_1_3.drop(BD_1_3.index[0:100], inplace = True)
BD_1_3.drop(BD_1_3.index[130:250], inplace = True)

BD_1_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_1_3.csv", index=False) 
BD_1_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_1_3.csv", delimiter = ",")

BD_1_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Walking_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_2_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_2_1.csv", delimiter = ",")
BD_2_1.columns = headerList
BD_2_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_2_1.head()

BD_2_1["AX"] = pd.to_numeric(BD_2_1["AX"], errors='coerce')
BD_2_1["AY"] = pd.to_numeric(BD_2_1["AY"], errors='coerce')
BD_2_1["AZ"] = pd.to_numeric(BD_2_1["AZ"], errors='coerce')

BD_2_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Forwards_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_2_1.drop(BD_2_1.index[0:140], inplace = True)
BD_2_1.drop(BD_2_1.index[30:250], inplace = True)

BD_2_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_2_1.csv", index=False) 
BD_2_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_2_1.csv", delimiter = ",")

BD_2_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Forwards_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_2_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_2_2.csv", delimiter = ",")
BD_2_2.columns = headerList
BD_2_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_2_2.head()

BD_2_2["AX"] = pd.to_numeric(BD_2_2["AX"], errors='coerce')
BD_2_2["AY"] = pd.to_numeric(BD_2_2["AY"], errors='coerce')
BD_2_2["AZ"] = pd.to_numeric(BD_2_2["AZ"], errors='coerce')

BD_2_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Forwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')
# Out:
# Text(0.5, 0, 'Time/s')

# %%
BD_2_2.drop(BD_2_2.index[0:145], inplace = True)
BD_2_2.drop(BD_2_2.index[25:250], inplace = True)

BD_2_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_2_2.csv", index=False) 
BD_2_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_2_2.csv", delimiter = ",")

BD_2_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Forwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_2_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_2_3.csv", delimiter = ",")
BD_2_3.columns = headerList
BD_2_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_2_3.head()

BD_2_3["AX"] = pd.to_numeric(BD_2_3["AX"], errors='coerce')
BD_2_3["AY"] = pd.to_numeric(BD_2_3["AY"], errors='coerce')
BD_2_3["AZ"] = pd.to_numeric(BD_2_3["AZ"], errors='coerce')

BD_2_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Forwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_2_3.drop(BD_2_3.index[0:160], inplace = True)
BD_2_3.drop(BD_2_3.index[18:250], inplace = True)

BD_2_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_2_3.csv", index=False) 
BD_2_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_2_3.csv", delimiter = ",")

BD_2_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Forwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_3_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_3_1.csv", delimiter = ",")
BD_3_1.columns = headerList
BD_3_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_3_1.head()

BD_3_1["AX"] = pd.to_numeric(BD_3_1["AX"], errors='coerce')
BD_3_1["AY"] = pd.to_numeric(BD_3_1["AY"], errors='coerce')
BD_3_1["AZ"] = pd.to_numeric(BD_3_1["AZ"], errors='coerce')

BD_3_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Backwards_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_3_1.drop(BD_3_1.index[0:150], inplace = True)
BD_3_1.drop(BD_3_1.index[35:250], inplace = True)

BD_3_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_3_1.csv", index=False) 
BD_3_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_3_1.csv", delimiter = ",")

BD_3_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             fontsize = 14,
            )

plt.title('BD_Falling_Backwards_1', fontsize = 20)
plt.ylabel('Accelerometer Data', fontsize = 20)
plt.xlabel('Samples', fontsize = 20)
plt.legend(fontsize = 20)

plt.show()

# %%
BD_3_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_3_2.csv", delimiter = ",")
BD_3_2.columns = headerList
BD_3_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_3_2.head()

BD_3_2["AX"] = pd.to_numeric(BD_3_2["AX"], errors='coerce')
BD_3_2["AY"] = pd.to_numeric(BD_3_2["AY"], errors='coerce')
BD_3_2["AZ"] = pd.to_numeric(BD_3_2["AZ"], errors='coerce')

BD_3_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Backwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_3_2.drop(BD_3_2.index[0:150], inplace = True)
BD_3_2.drop(BD_3_2.index[30:250], inplace = True)

BD_3_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_3_2.csv", index=False) 
BD_3_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_3_2.csv", delimiter = ",")

BD_3_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Backwards_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_3_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_3_3.csv", delimiter = ",")
BD_3_3.columns = headerList
BD_3_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_3_3.head()

BD_3_3["AX"] = pd.to_numeric(BD_3_3["AX"], errors='coerce')
BD_3_3["AY"] = pd.to_numeric(BD_3_3["AY"], errors='coerce')
BD_3_3["AZ"] = pd.to_numeric(BD_3_3["AZ"], errors='coerce')

BD_3_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Backwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_3_3.drop(BD_3_3.index[0:125], inplace = True)
BD_3_3.drop(BD_3_3.index[35:250], inplace = True)

BD_3_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_3_3.csv", index=False) 
BD_3_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_3_3.csv", delimiter = ",")

BD_3_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Backwards_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_4_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_4_1.csv", delimiter = ",")
BD_4_1.columns = headerList
BD_4_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_4_1.head()

BD_4_1["AX"] = pd.to_numeric(BD_4_1["AX"], errors='coerce')
BD_4_1["AY"] = pd.to_numeric(BD_4_1["AY"], errors='coerce')
BD_4_1["AZ"] = pd.to_numeric(BD_4_1["AZ"], errors='coerce')

BD_4_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Side_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_4_1.drop(BD_4_1.index[0:155], inplace = True)
BD_4_1.drop(BD_4_1.index[45:250], inplace = True)

BD_4_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_4_1.csv", index=False) 
BD_4_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_4_1.csv", delimiter = ",")

BD_4_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Side_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_4_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_4_2.csv", delimiter = ",")
BD_4_2.columns = headerList
BD_4_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_4_2.head()

BD_4_2["AX"] = pd.to_numeric(BD_4_2["AX"], errors='coerce')
BD_4_2["AY"] = pd.to_numeric(BD_4_2["AY"], errors='coerce')
BD_4_2["AZ"] = pd.to_numeric(BD_4_2["AZ"], errors='coerce')

BD_4_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Side_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_4_2.drop(BD_4_2.index[0:160], inplace = True)
BD_4_2.drop(BD_4_2.index[40:250], inplace = True)

BD_4_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_4_2.csv", index=False) 
BD_4_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_4_2.csv", delimiter = ",")

BD_4_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Side_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_4_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_4_3.csv", delimiter = ",")
BD_4_3.columns = headerList
BD_4_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_4_3.head()

BD_4_3["AX"] = pd.to_numeric(BD_4_3["AX"], errors='coerce')
BD_4_3["AY"] = pd.to_numeric(BD_4_3["AY"], errors='coerce')
BD_4_3["AZ"] = pd.to_numeric(BD_4_3["AZ"], errors='coerce')

BD_4_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Side_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_4_3.drop(BD_4_3.index[0:150], inplace = True)
BD_4_3.drop(BD_4_3.index[30:250], inplace = True)

BD_4_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_4_3.csv", index=False) 
BD_4_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_4_3.csv", delimiter = ",")

BD_4_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Falling_Side_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_5_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_5_1.csv", delimiter = ",")
BD_5_1.columns = headerList
BD_5_1.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_5_1.head()

BD_5_1["AX"] = pd.to_numeric(BD_5_1["AX"], errors='coerce')
BD_5_1["AY"] = pd.to_numeric(BD_5_1["AY"], errors='coerce')
BD_5_1["AZ"] = pd.to_numeric(BD_5_1["AZ"], errors='coerce')

BD_5_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Dropping_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_5_1.drop(BD_5_1.index[0:160], inplace = True)
BD_5_1.drop(BD_5_1.index[30:250], inplace = True)

BD_5_1.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_5_1.csv", index=False) 
BD_5_1 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_5_1.csv", delimiter = ",")

BD_5_1.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Dropping_1')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_5_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_5_2.csv", delimiter = ",")
BD_5_2.columns = headerList
BD_5_2.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_5_2.head()

BD_5_2["AX"] = pd.to_numeric(BD_5_2["AX"], errors='coerce')
BD_5_2["AY"] = pd.to_numeric(BD_5_2["AY"], errors='coerce')
BD_5_2["AZ"] = pd.to_numeric(BD_5_2["AZ"], errors='coerce')

BD_5_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Dropping_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_5_2.drop(BD_5_2.index[0:180], inplace = True)
BD_5_2.drop(BD_5_2.index[30:250], inplace = True)

BD_5_2.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_5_2.csv", index=False) 
BD_5_2 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_5_2.csv", delimiter = ",")

BD_5_2.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Dropping_2')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_5_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/filesBD_5_3.csv", delimiter = ",")
BD_5_3.columns = headerList
BD_5_3.drop(["GX", "GY", "GZ"], axis=1, inplace=True)
BD_5_3.head()

BD_5_3["AX"] = pd.to_numeric(BD_5_3["AX"], errors='coerce')
BD_5_3["AY"] = pd.to_numeric(BD_5_3["AY"], errors='coerce')
BD_5_3["AZ"] = pd.to_numeric(BD_5_3["AZ"], errors='coerce')

BD_5_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Dropping_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()

# %%
BD_5_3.drop(BD_5_3.index[0:160], inplace = True)
BD_5_3.drop(BD_5_3.index[30:250], inplace = True)

BD_5_3.to_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_5_3.csv", index=False) 
BD_5_3 = pd.read_csv("C:/Users/phuon/EDX/EPQDataAnalysis/_Extracted Data/filesBD_5_3.csv", delimiter = ",")

BD_5_3.plot(kind='line', #to produce a stacked area plot, each column must either be all pos. or all neg.
             stacked=False, #area plots are automatically stacked. Pass this for it to be unstacked. NaN would be defaulted as 0
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('BD_Dropping_3')
plt.ylabel('Accelerometer Data')
plt.xlabel('Time/s')

plt.show()
